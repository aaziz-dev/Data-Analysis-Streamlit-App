# %%
from pandas import read_csv
import pandas as pd
try:
    pd.set_option('display.max_columns', None) #pour afficher tous les colonnes
   

    fichier='BeansDataSet.csv'
    col=['Robusta', 'Arabica', 'Espresso', 'Lungo', 'Latté', 'Cappuccino']
    data=read_csv(fichier,names=col)
    print(data)

except:
    print('erreur de lecture du fichier')
# Out:
#                 Robusta  Arabica  Espresso  Lungo  Latté  Cappuccino
# Channel Region  Robusta  Arabica  Espresso  Lungo  Latte  Cappuccino
# Online  South     12669     9656      7561    214   2674        1338
#         South      7057     9810      9568   1762   3293        1776
#         South      6353     8808      7684   2405   3516        7844
# Store   South     13265     1196      4221   6404    507        1788
# ...                 ...      ...       ...    ...    ...         ...
#         South     29703    12051     16027  13135    182        2204
#         South     39228     1431       764   4510     93        2346
# Online  South     14531    15488     30243    437  14841        1867
# Store   South     10290     1981      2232   1038    168        2125
#         South      2787     1698      2510     65    477          52
#
# [441 rows x 6 columns]
